# %% [markdown]
# # 스크래핑 테스트

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time, random, datetime
import pandas as pd

def chromeWebdriver():
    chrome_service = ChromeService(executable_path=ChromeDriverManager().install())
    options = Options()
    options.add_experimental_option('detach', True)
    options.add_experimental_option('excludeSwitches', ['enable-logging'])
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'
    options.add_argument(f'user-agent={user_agent}')
    driver = webdriver.Chrome(service=chrome_service, options=options)
    return driver

# 바늘이야기 스마트 스토어 리뷰
url ='https://smartstore.naver.com/danchoo/products/5898525598/' # 상품 상세페이지 링크 변경해야 함.
driver = chromeWebdriver()
# 페이지가 모두 로드될 때까지 3초 기다려주도록
driver.implicitly_wait(3)
driver.get(url)

cnt = 1
review = []
for page in range(1, 2): # 상품의 리뷰 페이지수에 따라 range 범위 수정
    time.sleep(2)
    lis = driver.find_element(By.XPATH, f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul').find_elements(By.TAG_NAME, 'li')
    print(f"========================== page: {page}==========================")
    for li in lis:
        print(li.text)
        print(f'review_count: {cnt}\n')
        print("-"*30)
        cnt += 1
        
    time.sleep(random.uniform(0.5, 1))
    
    # 다음 페이지 버튼 클릭
    driver.find_element(By.CSS_SELECTOR, '#REVIEW > div > div._180GG7_7yx > div.cv6id6JEkg > div > div > a.fAUKm1ewwo._2Ar8-aEUTq').click()
    driver.implicitly_wait(7)

driver.quit()
# Out:
# [WDM] - Downloading: 100%|██████████| 6.46M/6.46M [00:00<00:00, 33.1MB/s]
# ========================== page: 1==========================
# 리뷰 더보기/접기
# 평점
# 5
# apfh******
# 22.11.08.
# 신고
# 색상: 09 지탄블루
# 예전에 동생이 잃어버린 것과 비슷하게 생긴 목도리를 뜨는 법을 유튜브 알고리즘에 의해 발견하고 바로 실 구매했습니다 ㅋㅋ 한나절이면 다 뜰 줄 알았는데 뜨개질 왕초보라 변형고무뜨기는 처음해봐서 처음에 몇 번 푸르고 다시하기도 하고 현생이 힘들어 아직 20cm도 못 떴네요 ㅜㅜ 빨리 마무리해서 목도리 하고 다니려구요~ 노란 거 다 뜨면 파란 거 뜨려구요 ㅎㅎ 생각보다 더 쿨톤느낌의 파란색이에요.
# 이미지 펼쳐보기
# 0
# review_count: 1
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# apfh******
# 22.11.08.
# 신고
# 색상: 06 버터옐로우
# 예전에 동생이 잃어버린 것과 비슷하게 생긴 목도리를 뜨는 법을 유튜브 알고리즘에 의해 발견하고 바로 실 구매했습니다 ㅋㅋ 한나절이면 다 뜰 줄 알았는데 뜨개질 왕초보라 변형고무뜨기는 처음해봐서 처음에 몇 번 푸르고 다시하기도 하고 현생이 힘들어 아직 20cm도 못 떴네요 ㅜㅜ 빨리 마무리해서 목도리 하고 다니려구요~
# 이미지 펼쳐보기
# 0
# review_count: 2
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# mr****
# 22.11.07.
# 신고
# 색상: 05 밀크코코아
# 친구들 선물하려고 미니 스궤어백이랑 강아지 겨울옷 떴어요. 예뻐요.
# 사진/비디오 수
# 5
# 이미지 펼쳐보기
# 0
# review_count: 3
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# ilov******
# 22.11.14.
# 신고
# 색상: 02 크림베이지
# 배송도 빠르고 실도 괜찮았어요! 실풀림이 있긴 했는데 5mm 코바늘로는 괜찮았어요ㅎㅎ 덕분에 모자 잘 떴습니다~
# 이미지 펼쳐보기
# 0
# review_count: 4
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# 88****
# 22.09.02.
# 신고
# 색상: 13 블랙
# 미니스퀘어백 ....중독
# 한번만 뜬사람은 없다는 말 못믿었는데
# 믿게됬어요....... 지금 6개 뜨고
# 실 또 주문했어요 ㅋㅋㅋ(마지막이길,,,)
#
# 미니스퀘어백 매력은 진짜 미니라고 생각하지만
# 코튼10으로 뜨면 진짜 작고 이쁘지만
# 지갑이랑 핸드폰만 들어가는 크기라
# 크게뜨고싶은 욕심에 버터6으로 여러 사이즈로 떠봤어요(다 1롤기준)
#
# 일단 제가느낀 재질은 코튼10은 좀 단단하고 여름에 어울리는 재질같고
# 버터6은 초가을-겨울에 어울리는 몽실한 부드러운 재질같아요 ~~
# 사진에 사이즈는 가로X세로X손잡이코수 에요
# 뜨시는분들 참고하시라고 올려요~~!
#
# 주변지인들한테 물어봤을때 10X10이 제일 인기가 많은거같아요. 실은 조금 남았어요
#
# 11X8은 실 모잘랏어요ㅜㅜ 손잡이 안쪽뜰때 몸통쪽은 빼뜨기 손잡이쪽은 짧은뜨기로해서 겨우 딱맞췄어요 . 실 모자를까바 조마조마
# 근데 저는 통통이버전도 귀엽고 매력있는거같아요
#
# 다들 떠보세요!!! 계속 뜨게되요!!!!
# 지인들도, 회사에서도, 심지어 병원 진료받으러갔을때도 직접뜬거냐고 너무 귀엽다고 해서 뿌듯
# 강추합니다 ~^^~
# 더보기
# 사진/비디오 수
# 6
# 이미지 펼쳐보기
# 4
# review_count: 5
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# sien******
# 22.11.10.
# 신고
# 색상: 10 피콕블루
# 뜨개질에 요즘 푹 빠져있는데 바늘이야기에서 벌써 네번째 구매에용 버터6실이 부드럽고 톡톡해서 아주 만족입니당 빨리 크림 컬러가 재입고 됐으면 좋겠어용 배송은 진짜 빨라요!
# 이미지 펼쳐보기
# 0
# review_count: 6
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# sara****
# 22.11.07.
# 신고
# 색상: 05 밀크코코아
# 목도리 뜨고 있어요! 색깔 딱 마음에 들어요
# 실이 좀 갈라져서 완전 초보자는 어려울 수 있을 것 같아요
# 이미지 펼쳐보기
# 0
# review_count: 7
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# sjs0*****
# 22.10.31.
# 신고
# 색상: 17 로즈드라제
# 카메라에는 이상하게나오지만 색 딱 예쁘고 좋아요 조금 어두운 분홍색?실이 잘풀리기는 한데 목도리 뜨기에는 좋은거같네용
# 이미지 펼쳐보기
# 0
# review_count: 8
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# houj*****
# 22.11.08.
# 신고
# 색상: 11 클라우드
# 넓은 목도리를 뜨려고 3개 구매했어요 ! 회색끼가 도는 바이올렛에 가까운 색인 것 같아요 ~
# 이미지 펼쳐보기
# 0
# review_count: 9
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 4
# hoho****
# 22.11.10.
# 신고
# 색상: 18 레드와인
# 색 맘에 들어요 아들램 조카 목도리 만들어 주려구용
# 이미지 펼쳐보기
# 0
# review_count: 10
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 4
# hoho****
# 22.11.10.
# 신고
# 색상: 06 버터옐로우
# 색 맘에 들어요 아들램 목도리 만들어 주려구용
# 이미지 펼쳐보기
# 0
# review_count: 11
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# duda*******
# 22.11.17.
# 신고
# 색상: 02 크림베이지
# 한달사용기재구매체커보드 가방 떠서 요긴하게 잘 들고 다니고있음
# 이미지 펼쳐보기
# 0
# review_count: 12
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# ckdt*****
# 22.11.14.
# 신고
# 색상: 04 라이트그레이
# 첫대면은 화면과다른색감이다싶었는데 완성하고나니예뿝니당
# 이미지 펼쳐보기
# 0
# review_count: 13
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# whee*****
# 22.11.03.
# 신고
# 색상: 02 크림베이지
# 버터 6!! 실 보들보들 너무 좋아요 ㅎㅎ 쁘띠 목도리 뜨고 있어요 마음에 듭니다
# 이미지 펼쳐보기
# 0
# review_count: 14
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# whee*****
# 22.11.03.
# 신고
# 색상: 17 로즈드라제
# 버터 6!! 실 보들보들 너무 좋아요 ㅎㅎ 쁘띠 목도리 뜨고 있어요 마음에 듭니다
# 이미지 펼쳐보기
# 0
# review_count: 15
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# sara****
# 22.11.07.
# 신고
# 색상: 20 에스프레소
# 목도리 뜨고 있어요!
# 실이 좀 갈라져서 완전 초보자는 어려울 수 있을 것 같아요
# 이미지 펼쳐보기
# 0
# review_count: 16
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# sara****
# 22.11.07.
# 신고
# 색상: 13 블랙
# 목도리 뜨고 있어요!
# 실이 좀 갈라져서 완전 초보자는 어려울 수 있을 것 같아요
# 이미지 펼쳐보기
# 0
# review_count: 17
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# sara****
# 22.11.07.
# 신고
# 색상: 02 크림베이지
# 목도리 뜨고 있어요!
# 실이 좀 갈라져서 완전 초보자는 어려울 수 있을 것 같아요
# 이미지 펼쳐보기
# 0
# review_count: 18
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 5
# ckdt*****
# 22.11.14.
# 신고
# 색상: 17 로즈드라제
# 색감이 완성하고나니 너므이뻐요
# 이미지 펼쳐보기
# 0
# review_count: 19
#
# ------------------------------
# 리뷰 더보기/접기
# 평점
# 4
# hoho****
# 22.11.10.
# 신고
# 색상: 02 크림베이지
# 실 갈라짐이 있긴 하지만 부들부들하고 저렴해서 맘에 듭니당
# 이미지 펼쳐보기
# 0
# review_count: 20
#
# ------------------------------

# %% [markdown]
# # 데이터프레임으로 정리(review 리스트로 뽑아내기)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time, random, datetime
import pandas as pd

def chromeWebdriver():
    chrome_service = ChromeService(executable_path=ChromeDriverManager().install())
    options = Options()
    options.add_experimental_option('detach', True)
    options.add_experimental_option('excludeSwitches', ['enable-logging'])
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'
    options.add_argument(f'user-agent={user_agent}')

    driver = webdriver.Chrome(service=chrome_service, options=options)
    return driver

# 바늘이야기 스마트 스토어 리뷰
url ='https://smartstore.naver.com/danchoo/products/5898525598/'
driver = chromeWebdriver()

# 페이지가 모두 로드될 때까지 3초 기다려주도록
driver.implicitly_wait(3)
driver.get(url)

cnt = 1
review = []
for page in range(1, 3):
    time.sleep(2)
    lis = driver.find_element(By.XPATH, f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul').find_elements(By.TAG_NAME, 'li')
    for li in lis:
        review.append(li.text)
#         review.append(li.text.split('\n')) # \n을 기준으로 문자열 나누어서 리스트 각각의 원소로 만들기
        cnt += 1
        
    time.sleep(random.uniform(0.5, 1))
    
    driver.find_element(By.CSS_SELECTOR, '#REVIEW > div > div._180GG7_7yx > div.cv6id6JEkg > div > div > a.fAUKm1ewwo._2Ar8-aEUTq').click()
    driver.implicitly_wait(7)

driver.quit()

# %%
df = pd.DataFrame(review)
df.head()
# Out:
#                                                    0
# 0  리뷰 더보기/접기\n평점\n5\napfh******\n22.11.08.\n신고\n색...
# 1  리뷰 더보기/접기\n평점\n5\napfh******\n22.11.08.\n신고\n색...
# 2  리뷰 더보기/접기\n평점\n5\nmr****\n22.11.07.\n신고\n색상: 0...
# 3  리뷰 더보기/접기\n평점\n5\nilov******\n22.11.14.\n신고\n색...
# 4  리뷰 더보기/접기\n평점\n5\n88****\n22.09.02.\n신고\n색상: 1...

# %% [markdown]
# # 문자열 나눠서 리스트 변환 추가
# li.text.split('\n')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time, random, datetime
import pandas as pd

def chromeWebdriver():
    chrome_service = ChromeService(executable_path=ChromeDriverManager().install())
    options = Options()
    options.add_experimental_option('detach', True)
    options.add_experimental_option('excludeSwitches', ['enable-logging'])
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36'
    options.add_argument(f'user-agent={user_agent}')

    driver = webdriver.Chrome(service=chrome_service, options=options)
    return driver

# 바늘이야기 스마트 스토어 리뷰
url ='https://smartstore.naver.com/danchoo/products/5898525598/'
driver = chromeWebdriver()

# 페이지가 모두 로드될 때까지 3초 기다려주도록
driver.implicitly_wait(3)
driver.get(url)

cnt = 1
review = []
for page in range(1, 3):
    time.sleep(2)
    lis = driver.find_element(By.XPATH, f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul').find_elements(By.TAG_NAME, 'li')
    for li in lis:
#         review.append(li.text)
        review.append(li.text.split('\n')) # '\n'을 기준으로 문자열 나누어서 리스트 각각의 원소로 만들기
        cnt += 1
        
    time.sleep(random.uniform(0.5, 1))
    
    driver.find_element(By.CSS_SELECTOR, '#REVIEW > div > div._180GG7_7yx > div.cv6id6JEkg > div > div > a.fAUKm1ewwo._2Ar8-aEUTq').click()
    driver.implicitly_wait(7)

driver.quit()

# %%
df = pd.DataFrame(review)
df.head()
# df.to_csv('butter6_review.txt',sep="\t")
# Out:
#           0   1  2           3          4   5             6   \
# 0  리뷰 더보기/접기  평점  5  apfh******  22.11.08.  신고   색상: 09 지탄블루
# 1  리뷰 더보기/접기  평점  5  apfh******  22.11.08.  신고  색상: 06 버터옐로우
# 2  리뷰 더보기/접기  평점  5      mr****  22.11.07.  신고  색상: 05 밀크코코아
# 3  리뷰 더보기/접기  평점  5  ilov******  22.11.14.  신고  색상: 02 크림베이지
# 4  리뷰 더보기/접기  평점  5      88****  22.09.02.  신고     색상: 13 블랙
#
#                                                   7                     8   \
# 0  예전에 동생이 잃어버린 것과 비슷하게 생긴 목도리를 뜨는 법을 유튜브 알고리즘에 의...              이미지 펼쳐보기
# 1  예전에 동생이 잃어버린 것과 비슷하게 생긴 목도리를 뜨는 법을 유튜브 알고리즘에 의...              이미지 펼쳐보기
# 2              친구들 선물하려고 미니 스궤어백이랑 강아지 겨울옷 떴어요. 예뻐요.              사진/비디오 수
# 3  배송도 빠르고 실도 괜찮았어요! 실풀림이 있긴 했는데 5mm 코바늘로는 괜찮았어요ㅎ...              이미지 펼쳐보기
# 4                                      미니스퀘어백 ....중독  한번만 뜬사람은 없다는 말 못믿었는데
#
#                       9   ...                         25    26  \
# 0                      0  ...                       None  None
# 1                      0  ...                       None  None
# 2                      5  ...                       None  None
# 3                      0  ...                       None  None
# 4  믿게됬어요....... 지금 6개 뜨고  ...  근데 저는 통통이버전도 귀엽고 매력있는거같아요
#
#                        27                                                 28  \
# 0                    None                                               None
# 1                    None                                               None
# 2                    None                                               None
# 3                    None                                               None
# 4  다들 떠보세요!!! 계속 뜨게되요!!!!  지인들도, 회사에서도, 심지어 병원 진료받으러갔을때도 직접뜬거냐고 너무 귀엽다고 해...
#
#            29    30        31    32        33    34
# 0        None  None      None  None      None  None
# 1        None  None      None  None      None  None
# 2        None  None      None  None      None  None
# 3        None  None      None  None      None  None
# 4  강추합니다 ~^^~   더보기  사진/비디오 수     6  이미지 펼쳐보기     4
#
# [5 rows x 35 columns]
